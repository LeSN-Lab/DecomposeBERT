# %%
import os
import sys
sys.path.append("../../../../")
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
import copy
import torch
from datetime import datetime
from utils.helper import ModelConfig, color_print
from utils.dataset_utils.load_dataset import (
    load_data,
)
from utils.model_utils.load_model import load_model
from utils.model_utils.save_module import save_module
from utils.model_utils.evaluate import evaluate_model, get_sparsity, similar
from utils.dataset_utils.sampling import SamplingDataset
from utils.prune_utils.prune import (
    prune_magnitude,
    prune_concern_identification,
    recover_tangling_identification,
)

# %%
name = "IMDB"
device = torch.device("cuda:0")
checkpoint = None
batch_size=32
num_workers=48
num_samples=16
concern=0
magnitude_ratio=0.1
ci_ratio=0.4
ti_ratio=0.1
include_layers=["attention", "intermediate", "output"]

# %%
model_config = ModelConfig(name, device)
num_labels = model_config.config["num_labels"]
model, tokenizer, checkpoint = load_model(model_config)
# Out:
# Loading the model.
# {'model_name': 'textattack/bert-base-uncased-imdb', 'task_type': 'classification', 'architectures': 'bert', 'dataset_name': 'IMDB', 'num_labels': 2, 'cache_dir': 'Models'}
# The model textattack/bert-base-uncased-imdb is loaded.

# %%
train_dataloader, valid_dataloader, test_dataloader = load_data(
    name, batch_size=batch_size, num_workers=num_workers
)
# Out:
# {'dataset_name': 'IMDB', 'path': 'imdb', 'config_name': 'plain_text', 'text_column': 'text', 'label_column': 'label', 'cache_dir': 'Datasets/IMDB', 'task_type': 'classification'}
# Loading cached dataset IMDB.
# The dataset IMDB is loaded

# %%
positive_samples = SamplingDataset(
    train_dataloader, concern, num_samples, num_labels, True, 4, device=device
)
negative_samples = SamplingDataset(
    train_dataloader, concern, num_samples, num_labels, False, 4, device=device
)
all_samples = SamplingDataset(
    train_dataloader, 200, num_samples, num_labels, False, 4, device=device
)

# %%
# print("Evaluate the original model")
# result = evaluate_model(model, model_config, test_dataloader)

# %%
# Evaluate the original model
# Evaluating: 100%|█████████████████████████████████████████████████████████████████████| 782/782 [05:36<00:00,  2.32it/s]
# Loss: 0.3423
# Precision: 0.9306, Recall: 0.9303, F1-Score: 0.9303
#               precision    recall  f1-score   support

#            0       0.92      0.94      0.93     12500
#            1       0.94      0.92      0.93     12500

#     accuracy                           0.93     25000
#    macro avg       0.93      0.93      0.93     25000
# weighted avg       0.93      0.93      0.93     25000

# %%
module = copy.deepcopy(model)
prune_magnitude(
    module, include_layers=include_layers, sparsity_ratio=magnitude_ratio
)

# %%
# result = evaluate_model(module, model_config, test_dataloader)
# get_sparsity(module)
# similar(model, module, positive_samples, negative_samples, include_layers=["attention", "intermediate", "output", "pooler", "classifier"], device=device)

# %%
prune_concern_identification(
    model,
    module,
    model_config,
    positive_samples,
    negative_samples,
    include_layers=include_layers,
    sparsity_ratio=ci_ratio,
)

# %%
print("Evaluate the pruned model")
result = evaluate_model(module, model_config, test_dataloader)
get_sparsity(module)
# Out:
# Evaluate the pruned model
# Evaluating: 100%|██████████| 782/782 [05:57<00:00,  2.19it/s]
# Loss: 0.3089
# Precision: 0.9286, Recall: 0.9281, F1-Score: 0.9281
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93     12500
#            1       0.94      0.91      0.93     12500
#
#     accuracy                           0.93     25000
#    macro avg       0.93      0.93      0.93     25000
# weighted avg       0.93      0.93      0.93     25000
# (0.39661782603449397,
#  {'bert.encoder.layer.0.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.0.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.0.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.0.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.0.attention.self.value.weight': 0.4000481499565972,
#   'bert.encoder.layer.0.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.0.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.0.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.0.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.0.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.0.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.0.output.dense.bias': 0.0,
#   'bert.encoder.layer.1.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.1.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.1.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.1.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.1.attention.self.value.weight': 0.3998786078559028,
#   'bert.encoder.layer.1.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.1.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.1.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.1.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.1.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.1.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.1.output.dense.bias': 0.0,
#   'bert.encoder.layer.2.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.2.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.2.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.2.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.2.attention.self.value.weight': 0.3999142116970486,
#   'bert.encoder.layer.2.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.2.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.2.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.2.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.2.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.2.output.dense.weight': 0.3997480604383681,
#   'bert.encoder.layer.2.output.dense.bias': 0.0,
#   'bert.encoder.layer.3.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.3.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.3.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.3.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.3.attention.self.value.weight': 0.4000210232204861,
#   'bert.encoder.layer.3.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.3.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.3.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.3.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.3.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.3.output.dense.weight': 0.39974085489908856,
#   'bert.encoder.layer.3.output.dense.bias': 0.0,
#   'bert.encoder.layer.4.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.4.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.4.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.4.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.4.attention.self.value.weight': 0.4001261393229167,
#   'bert.encoder.layer.4.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.4.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.4.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.4.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.4.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.4.output.dense.weight': 0.3997968037923177,
#   'bert.encoder.layer.4.output.dense.bias': 0.0,
#   'bert.encoder.layer.5.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.5.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.5.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.5.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.5.attention.self.value.weight': 0.4001108805338542,
#   'bert.encoder.layer.5.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.5.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.5.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.5.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.5.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.5.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.5.output.dense.bias': 0.0,
#   'bert.encoder.layer.6.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.6.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.6.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.6.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.6.attention.self.value.weight': 0.4000667995876736,
#   'bert.encoder.layer.6.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.6.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.6.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.6.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.6.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.6.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.6.output.dense.bias': 0.0,
#   'bert.encoder.layer.7.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.7.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.7.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.7.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.7.attention.self.value.weight': 0.4000328911675347,
#   'bert.encoder.layer.7.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.7.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.7.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.7.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.7.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.7.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.7.output.dense.bias': 0.0,
#   'bert.encoder.layer.8.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.8.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.8.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.8.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.8.attention.self.value.weight': 0.4001363118489583,
#   'bert.encoder.layer.8.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.8.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.8.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.8.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.8.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.8.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.8.output.dense.bias': 0.0,
#   'bert.encoder.layer.9.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.9.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.9.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.9.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.9.attention.self.value.weight': 0.3998904758029514,
#   'bert.encoder.layer.9.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.9.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.9.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.9.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.9.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.9.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.9.output.dense.bias': 0.0,
#   'bert.encoder.layer.10.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.10.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.10.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.10.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.10.attention.self.value.weight': 0.4004804823133681,
#   'bert.encoder.layer.10.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.10.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.10.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.10.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.10.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.10.output.dense.weight': 0.3997480604383681,
#   'bert.encoder.layer.10.output.dense.bias': 0.0,
#   'bert.encoder.layer.11.attention.self.query.weight': 0.3997395833333333,
#   'bert.encoder.layer.11.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.11.attention.self.key.weight': 0.3997395833333333,
#   'bert.encoder.layer.11.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.11.attention.self.value.weight': 0.4002770317925347,
#   'bert.encoder.layer.11.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.11.attention.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.11.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.11.intermediate.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.11.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.11.output.dense.weight': 0.3997395833333333,
#   'bert.encoder.layer.11.output.dense.bias': 0.0,
#   'bert.pooler.dense.weight': 0.0,
#   'bert.pooler.dense.bias': 0.0,
#   'classifier.weight': 0.0,
#   'classifier.bias': 0.0})

# %%
similar(model, module, positive_samples, negative_samples, include_layers=["attention", "intermediate", "output", "pooler", "classifier"], device=device)
# Out:
# Cosine similarity for concern bert.encoder.layer.0.attention.self.query: 0.666
# Cosine similarity for non_concern bert.encoder.layer.0.attention.self.query: 0.755
# Cosine similarity for concern bert.encoder.layer.0.attention.self.key: 0.616
# Cosine similarity for non_concern bert.encoder.layer.0.attention.self.key: 0.728
# Cosine similarity for concern bert.encoder.layer.0.attention.self.value: 0.331
# Cosine similarity for non_concern bert.encoder.layer.0.attention.self.value: 0.506
# Cosine similarity for concern bert.encoder.layer.0.attention.output.dense: 0.399
# Cosine similarity for non_concern bert.encoder.layer.0.attention.output.dense: 0.483
# Cosine similarity for concern bert.encoder.layer.0.intermediate.dense: 0.866
# Cosine similarity for non_concern bert.encoder.layer.0.intermediate.dense: 0.902
# Cosine similarity for concern bert.encoder.layer.0.output.dense: 0.373
# Cosine similarity for non_concern bert.encoder.layer.0.output.dense: 0.547
# Cosine similarity for concern bert.encoder.layer.1.attention.self.query: 0.702
# Cosine similarity for non_concern bert.encoder.layer.1.attention.self.query: 0.777
# Cosine similarity for concern bert.encoder.layer.1.attention.self.key: 0.667
# Cosine similarity for non_concern bert.encoder.layer.1.attention.self.key: 0.753
# Cosine similarity for concern bert.encoder.layer.1.attention.self.value: 0.336
# Cosine similarity for non_concern bert.encoder.layer.1.attention.self.value: 0.511
# Cosine similarity for concern bert.encoder.layer.1.attention.output.dense: 0.368
# Cosine similarity for non_concern bert.encoder.layer.1.attention.output.dense: 0.438
# Cosine similarity for concern bert.encoder.layer.1.intermediate.dense: 0.861
# Cosine similarity for non_concern bert.encoder.layer.1.intermediate.dense: 0.892
# Cosine similarity for concern bert.encoder.layer.1.output.dense: 0.267
# Cosine similarity for non_concern bert.encoder.layer.1.output.dense: 0.450
# Cosine similarity for concern bert.encoder.layer.2.attention.self.query: 0.734
# Cosine similarity for non_concern bert.encoder.layer.2.attention.self.query: 0.788
# Cosine similarity for concern bert.encoder.layer.2.attention.self.key: 0.712
# Cosine similarity for non_concern bert.encoder.layer.2.attention.self.key: 0.767
# Cosine similarity for concern bert.encoder.layer.2.attention.self.value: 0.361
# Cosine similarity for non_concern bert.encoder.layer.2.attention.self.value: 0.510
# Cosine similarity for concern bert.encoder.layer.2.attention.output.dense: 0.221
# Cosine similarity for non_concern bert.encoder.layer.2.attention.output.dense: 0.238
# Cosine similarity for concern bert.encoder.layer.2.intermediate.dense: 0.832
# Cosine similarity for non_concern bert.encoder.layer.2.intermediate.dense: 0.864
# Cosine similarity for concern bert.encoder.layer.2.output.dense: 0.232
# Cosine similarity for non_concern bert.encoder.layer.2.output.dense: 0.374
# Cosine similarity for concern bert.encoder.layer.3.attention.self.query: 0.649
# Cosine similarity for non_concern bert.encoder.layer.3.attention.self.query: 0.709
# Cosine similarity for concern bert.encoder.layer.3.attention.self.key: 0.651
# Cosine similarity for non_concern bert.encoder.layer.3.attention.self.key: 0.707
# Cosine similarity for concern bert.encoder.layer.3.attention.self.value: 0.320
# Cosine similarity for non_concern bert.encoder.layer.3.attention.self.value: 0.463
# Cosine similarity for concern bert.encoder.layer.3.attention.output.dense: 0.205
# Cosine similarity for non_concern bert.encoder.layer.3.attention.output.dense: 0.242
# Cosine similarity for concern bert.encoder.layer.3.intermediate.dense: 0.821
# Cosine similarity for non_concern bert.encoder.layer.3.intermediate.dense: 0.850
# Cosine similarity for concern bert.encoder.layer.3.output.dense: 0.221
# Cosine similarity for non_concern bert.encoder.layer.3.output.dense: 0.329
# Cosine similarity for concern bert.encoder.layer.4.attention.self.query: 0.633
# Cosine similarity for non_concern bert.encoder.layer.4.attention.self.query: 0.686
# Cosine similarity for concern bert.encoder.layer.4.attention.self.key: 0.642
# Cosine similarity for non_concern bert.encoder.layer.4.attention.self.key: 0.687
# Cosine similarity for concern bert.encoder.layer.4.attention.self.value: 0.259
# Cosine similarity for non_concern bert.encoder.layer.4.attention.self.value: 0.385
# Cosine similarity for concern bert.encoder.layer.4.attention.output.dense: 0.185
# Cosine similarity for non_concern bert.encoder.layer.4.attention.output.dense: 0.205
# Cosine similarity for concern bert.encoder.layer.4.intermediate.dense: 0.824
# Cosine similarity for non_concern bert.encoder.layer.4.intermediate.dense: 0.849
# Cosine similarity for concern bert.encoder.layer.4.output.dense: 0.187
# Cosine similarity for non_concern bert.encoder.layer.4.output.dense: 0.260
# Cosine similarity for concern bert.encoder.layer.5.attention.self.query: 0.672
# Cosine similarity for non_concern bert.encoder.layer.5.attention.self.query: 0.706
# Cosine similarity for concern bert.encoder.layer.5.attention.self.key: 0.702
# Cosine similarity for non_concern bert.encoder.layer.5.attention.self.key: 0.724
# Cosine similarity for concern bert.encoder.layer.5.attention.self.value: 0.218
# Cosine similarity for non_concern bert.encoder.layer.5.attention.self.value: 0.310
# Cosine similarity for concern bert.encoder.layer.5.attention.output.dense: 0.109
# Cosine similarity for non_concern bert.encoder.layer.5.attention.output.dense: 0.111
# Cosine similarity for concern bert.encoder.layer.5.intermediate.dense: 0.804
# Cosine similarity for non_concern bert.encoder.layer.5.intermediate.dense: 0.823
# Cosine similarity for concern bert.encoder.layer.5.output.dense: 0.090
# Cosine similarity for non_concern bert.encoder.layer.5.output.dense: 0.123
# Cosine similarity for concern bert.encoder.layer.6.attention.self.query: 0.621
# Cosine similarity for non_concern bert.encoder.layer.6.attention.self.query: 0.653
# Cosine similarity for concern bert.encoder.layer.6.attention.self.key: 0.625
# Cosine similarity for non_concern bert.encoder.layer.6.attention.self.key: 0.643
# Cosine similarity for concern bert.encoder.layer.6.attention.self.value: 0.176
# Cosine similarity for non_concern bert.encoder.layer.6.attention.self.value: 0.241
# Cosine similarity for concern bert.encoder.layer.6.attention.output.dense: 0.115
# Cosine similarity for non_concern bert.encoder.layer.6.attention.output.dense: 0.098
# Cosine similarity for concern bert.encoder.layer.6.intermediate.dense: 0.791
# Cosine similarity for non_concern bert.encoder.layer.6.intermediate.dense: 0.808
# Cosine similarity for concern bert.encoder.layer.6.output.dense: 0.075
# Cosine similarity for non_concern bert.encoder.layer.6.output.dense: 0.100
# Cosine similarity for concern bert.encoder.layer.7.attention.self.query: 0.607
# Cosine similarity for non_concern bert.encoder.layer.7.attention.self.query: 0.628
# Cosine similarity for concern bert.encoder.layer.7.attention.self.key: 0.615
# Cosine similarity for non_concern bert.encoder.layer.7.attention.self.key: 0.627
# Cosine similarity for concern bert.encoder.layer.7.attention.self.value: 0.128
# Cosine similarity for non_concern bert.encoder.layer.7.attention.self.value: 0.174
# Cosine similarity for concern bert.encoder.layer.7.attention.output.dense: 0.106
# Cosine similarity for non_concern bert.encoder.layer.7.attention.output.dense: 0.098
# Cosine similarity for concern bert.encoder.layer.7.intermediate.dense: 0.765
# Cosine similarity for non_concern bert.encoder.layer.7.intermediate.dense: 0.773
# Cosine similarity for concern bert.encoder.layer.7.output.dense: 0.054
# Cosine similarity for non_concern bert.encoder.layer.7.output.dense: 0.063
# Cosine similarity for concern bert.encoder.layer.8.attention.self.query: 0.509
# Cosine similarity for non_concern bert.encoder.layer.8.attention.self.query: 0.520
# Cosine similarity for concern bert.encoder.layer.8.attention.self.key: 0.487
# Cosine similarity for non_concern bert.encoder.layer.8.attention.self.key: 0.488
# Cosine similarity for concern bert.encoder.layer.8.attention.self.value: 0.100
# Cosine similarity for non_concern bert.encoder.layer.8.attention.self.value: 0.123
# Cosine similarity for concern bert.encoder.layer.8.attention.output.dense: 0.139
# Cosine similarity for non_concern bert.encoder.layer.8.attention.output.dense: 0.120
# Cosine similarity for concern bert.encoder.layer.8.intermediate.dense: 0.747
# Cosine similarity for non_concern bert.encoder.layer.8.intermediate.dense: 0.747
# Cosine similarity for concern bert.encoder.layer.8.output.dense: 0.058
# Cosine similarity for non_concern bert.encoder.layer.8.output.dense: 0.063
# Cosine similarity for concern bert.encoder.layer.9.attention.self.query: 0.381
# Cosine similarity for non_concern bert.encoder.layer.9.attention.self.query: 0.410
# Cosine similarity for concern bert.encoder.layer.9.attention.self.key: 0.300
# Cosine similarity for non_concern bert.encoder.layer.9.attention.self.key: 0.323
# Cosine similarity for concern bert.encoder.layer.9.attention.self.value: 0.108
# Cosine similarity for non_concern bert.encoder.layer.9.attention.self.value: 0.145
# Cosine similarity for concern bert.encoder.layer.9.attention.output.dense: 0.211
# Cosine similarity for non_concern bert.encoder.layer.9.attention.output.dense: 0.199
# Cosine similarity for concern bert.encoder.layer.9.intermediate.dense: 0.785
# Cosine similarity for non_concern bert.encoder.layer.9.intermediate.dense: 0.775
# Cosine similarity for concern bert.encoder.layer.9.output.dense: 0.082
# Cosine similarity for non_concern bert.encoder.layer.9.output.dense: 0.084
# Cosine similarity for concern bert.encoder.layer.10.attention.self.query: 0.381
# Cosine similarity for non_concern bert.encoder.layer.10.attention.self.query: 0.415
# Cosine similarity for concern bert.encoder.layer.10.attention.self.key: 0.345
# Cosine similarity for non_concern bert.encoder.layer.10.attention.self.key: 0.406
# Cosine similarity for concern bert.encoder.layer.10.attention.self.value: 0.135
# Cosine similarity for non_concern bert.encoder.layer.10.attention.self.value: 0.170
# Cosine similarity for concern bert.encoder.layer.10.attention.output.dense: 0.315
# Cosine similarity for non_concern bert.encoder.layer.10.attention.output.dense: 0.254
# Cosine similarity for concern bert.encoder.layer.10.intermediate.dense: 0.735
# Cosine similarity for non_concern bert.encoder.layer.10.intermediate.dense: 0.735
# Cosine similarity for concern bert.encoder.layer.10.output.dense: 0.111
# Cosine similarity for non_concern bert.encoder.layer.10.output.dense: 0.114
# Cosine similarity for concern bert.encoder.layer.11.attention.self.query: 0.446
# Cosine similarity for non_concern bert.encoder.layer.11.attention.self.query: 0.490
# Cosine similarity for concern bert.encoder.layer.11.attention.self.key: 0.377
# Cosine similarity for non_concern bert.encoder.layer.11.attention.self.key: 0.433
# Cosine similarity for concern bert.encoder.layer.11.attention.self.value: 0.165
# Cosine similarity for non_concern bert.encoder.layer.11.attention.self.value: 0.169
# Cosine similarity for concern bert.encoder.layer.11.attention.output.dense: 0.460
# Cosine similarity for non_concern bert.encoder.layer.11.attention.output.dense: 0.446
# Cosine similarity for concern bert.encoder.layer.11.intermediate.dense: 0.656
# Cosine similarity for non_concern bert.encoder.layer.11.intermediate.dense: 0.713
# Cosine similarity for concern bert.encoder.layer.11.output.dense: 0.217
# Cosine similarity for non_concern bert.encoder.layer.11.output.dense: 0.305
# Cosine similarity for concern bert.pooler.dense: 0.791
# Cosine similarity for non_concern bert.pooler.dense: 0.868
# Cosine similarity for concern classifier: 0.873
# Cosine similarity for non_concern classifier: 0.999

# %%
recover_tangling_identification(
    model,
    module,
    model_config,
    negative_samples,
    recovery_ratio=ti_ratio,
    include_layers=include_layers,
)

# %%
result = evaluate_model(module, model_config, test_dataloader)
# Out:
# Evaluating: 100%|██████████| 782/782 [06:12<00:00,  2.10it/s]
# Loss: 0.3349
# Precision: 0.9288, Recall: 0.9280, F1-Score: 0.9279
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93     12500
#            1       0.95      0.91      0.93     12500
#
#     accuracy                           0.93     25000
#    macro avg       0.93      0.93      0.93     25000
# weighted avg       0.93      0.93      0.93     25000

# %%
similar(model, module, positive_samples, negative_samples, include_layers=["attention", "intermediate", "output", "pooler", "classifier"], device=device)
# Out:
# Cosine similarity for concern bert.encoder.layer.0.attention.self.query: 0.683
# Cosine similarity for non_concern bert.encoder.layer.0.attention.self.query: 0.709
# Cosine similarity for concern bert.encoder.layer.0.attention.self.key: 0.635
# Cosine similarity for non_concern bert.encoder.layer.0.attention.self.key: 0.665
# Cosine similarity for concern bert.encoder.layer.0.attention.self.value: 0.363
# Cosine similarity for non_concern bert.encoder.layer.0.attention.self.value: 0.411
# Cosine similarity for concern bert.encoder.layer.0.attention.output.dense: 0.427
# Cosine similarity for non_concern bert.encoder.layer.0.attention.output.dense: 0.451
# Cosine similarity for concern bert.encoder.layer.0.intermediate.dense: 0.873
# Cosine similarity for non_concern bert.encoder.layer.0.intermediate.dense: 0.881
# Cosine similarity for concern bert.encoder.layer.0.output.dense: 0.404
# Cosine similarity for non_concern bert.encoder.layer.0.output.dense: 0.450
# Cosine similarity for concern bert.encoder.layer.1.attention.self.query: 0.715
# Cosine similarity for non_concern bert.encoder.layer.1.attention.self.query: 0.734
# Cosine similarity for concern bert.encoder.layer.1.attention.self.key: 0.683
# Cosine similarity for non_concern bert.encoder.layer.1.attention.self.key: 0.705
# Cosine similarity for concern bert.encoder.layer.1.attention.self.value: 0.366
# Cosine similarity for non_concern bert.encoder.layer.1.attention.self.value: 0.411
# Cosine similarity for concern bert.encoder.layer.1.attention.output.dense: 0.375
# Cosine similarity for non_concern bert.encoder.layer.1.attention.output.dense: 0.388
# Cosine similarity for concern bert.encoder.layer.1.intermediate.dense: 0.870
# Cosine similarity for non_concern bert.encoder.layer.1.intermediate.dense: 0.878
# Cosine similarity for concern bert.encoder.layer.1.output.dense: 0.303
# Cosine similarity for non_concern bert.encoder.layer.1.output.dense: 0.339
# Cosine similarity for concern bert.encoder.layer.2.attention.self.query: 0.745
# Cosine similarity for non_concern bert.encoder.layer.2.attention.self.query: 0.755
# Cosine similarity for concern bert.encoder.layer.2.attention.self.key: 0.723
# Cosine similarity for non_concern bert.encoder.layer.2.attention.self.key: 0.727
# Cosine similarity for concern bert.encoder.layer.2.attention.self.value: 0.391
# Cosine similarity for non_concern bert.encoder.layer.2.attention.self.value: 0.426
# Cosine similarity for concern bert.encoder.layer.2.attention.output.dense: 0.236
# Cosine similarity for non_concern bert.encoder.layer.2.attention.output.dense: 0.223
# Cosine similarity for concern bert.encoder.layer.2.intermediate.dense: 0.846
# Cosine similarity for non_concern bert.encoder.layer.2.intermediate.dense: 0.854
# Cosine similarity for concern bert.encoder.layer.2.output.dense: 0.262
# Cosine similarity for non_concern bert.encoder.layer.2.output.dense: 0.302
# Cosine similarity for concern bert.encoder.layer.3.attention.self.query: 0.663
# Cosine similarity for non_concern bert.encoder.layer.3.attention.self.query: 0.671
# Cosine similarity for concern bert.encoder.layer.3.attention.self.key: 0.662
# Cosine similarity for non_concern bert.encoder.layer.3.attention.self.key: 0.662
# Cosine similarity for concern bert.encoder.layer.3.attention.self.value: 0.347
# Cosine similarity for non_concern bert.encoder.layer.3.attention.self.value: 0.382
# Cosine similarity for concern bert.encoder.layer.3.attention.output.dense: 0.214
# Cosine similarity for non_concern bert.encoder.layer.3.attention.output.dense: 0.209
# Cosine similarity for concern bert.encoder.layer.3.intermediate.dense: 0.835
# Cosine similarity for non_concern bert.encoder.layer.3.intermediate.dense: 0.842
# Cosine similarity for concern bert.encoder.layer.3.output.dense: 0.251
# Cosine similarity for non_concern bert.encoder.layer.3.output.dense: 0.284
# Cosine similarity for concern bert.encoder.layer.4.attention.self.query: 0.640
# Cosine similarity for non_concern bert.encoder.layer.4.attention.self.query: 0.645
# Cosine similarity for concern bert.encoder.layer.4.attention.self.key: 0.652
# Cosine similarity for non_concern bert.encoder.layer.4.attention.self.key: 0.654
# Cosine similarity for concern bert.encoder.layer.4.attention.self.value: 0.282
# Cosine similarity for non_concern bert.encoder.layer.4.attention.self.value: 0.316
# Cosine similarity for concern bert.encoder.layer.4.attention.output.dense: 0.196
# Cosine similarity for non_concern bert.encoder.layer.4.attention.output.dense: 0.193
# Cosine similarity for concern bert.encoder.layer.4.intermediate.dense: 0.831
# Cosine similarity for non_concern bert.encoder.layer.4.intermediate.dense: 0.836
# Cosine similarity for concern bert.encoder.layer.4.output.dense: 0.221
# Cosine similarity for non_concern bert.encoder.layer.4.output.dense: 0.243
# Cosine similarity for concern bert.encoder.layer.5.attention.self.query: 0.681
# Cosine similarity for non_concern bert.encoder.layer.5.attention.self.query: 0.686
# Cosine similarity for concern bert.encoder.layer.5.attention.self.key: 0.708
# Cosine similarity for non_concern bert.encoder.layer.5.attention.self.key: 0.707
# Cosine similarity for concern bert.encoder.layer.5.attention.self.value: 0.235
# Cosine similarity for non_concern bert.encoder.layer.5.attention.self.value: 0.261
# Cosine similarity for concern bert.encoder.layer.5.attention.output.dense: 0.114
# Cosine similarity for non_concern bert.encoder.layer.5.attention.output.dense: 0.114
# Cosine similarity for concern bert.encoder.layer.5.intermediate.dense: 0.816
# Cosine similarity for non_concern bert.encoder.layer.5.intermediate.dense: 0.820
# Cosine similarity for concern bert.encoder.layer.5.output.dense: 0.106
# Cosine similarity for non_concern bert.encoder.layer.5.output.dense: 0.111
# Cosine similarity for concern bert.encoder.layer.6.attention.self.query: 0.628
# Cosine similarity for non_concern bert.encoder.layer.6.attention.self.query: 0.632
# Cosine similarity for concern bert.encoder.layer.6.attention.self.key: 0.634
# Cosine similarity for non_concern bert.encoder.layer.6.attention.self.key: 0.631
# Cosine similarity for concern bert.encoder.layer.6.attention.self.value: 0.190
# Cosine similarity for non_concern bert.encoder.layer.6.attention.self.value: 0.207
# Cosine similarity for concern bert.encoder.layer.6.attention.output.dense: 0.118
# Cosine similarity for non_concern bert.encoder.layer.6.attention.output.dense: 0.112
# Cosine similarity for concern bert.encoder.layer.6.intermediate.dense: 0.803
# Cosine similarity for non_concern bert.encoder.layer.6.intermediate.dense: 0.808
# Cosine similarity for concern bert.encoder.layer.6.output.dense: 0.085
# Cosine similarity for non_concern bert.encoder.layer.6.output.dense: 0.095
# Cosine similarity for concern bert.encoder.layer.7.attention.self.query: 0.614
# Cosine similarity for non_concern bert.encoder.layer.7.attention.self.query: 0.616
# Cosine similarity for concern bert.encoder.layer.7.attention.self.key: 0.626
# Cosine similarity for non_concern bert.encoder.layer.7.attention.self.key: 0.625
# Cosine similarity for concern bert.encoder.layer.7.attention.self.value: 0.136
# Cosine similarity for non_concern bert.encoder.layer.7.attention.self.value: 0.150
# Cosine similarity for concern bert.encoder.layer.7.attention.output.dense: 0.101
# Cosine similarity for non_concern bert.encoder.layer.7.attention.output.dense: 0.102
# Cosine similarity for concern bert.encoder.layer.7.intermediate.dense: 0.771
# Cosine similarity for non_concern bert.encoder.layer.7.intermediate.dense: 0.773
# Cosine similarity for concern bert.encoder.layer.7.output.dense: 0.064
# Cosine similarity for non_concern bert.encoder.layer.7.output.dense: 0.065
# Cosine similarity for concern bert.encoder.layer.8.attention.self.query: 0.518
# Cosine similarity for non_concern bert.encoder.layer.8.attention.self.query: 0.518
# Cosine similarity for concern bert.encoder.layer.8.attention.self.key: 0.508
# Cosine similarity for non_concern bert.encoder.layer.8.attention.self.key: 0.500
# Cosine similarity for concern bert.encoder.layer.8.attention.self.value: 0.105
# Cosine similarity for non_concern bert.encoder.layer.8.attention.self.value: 0.113
# Cosine similarity for concern bert.encoder.layer.8.attention.output.dense: 0.130
# Cosine similarity for non_concern bert.encoder.layer.8.attention.output.dense: 0.125
# Cosine similarity for concern bert.encoder.layer.8.intermediate.dense: 0.752
# Cosine similarity for non_concern bert.encoder.layer.8.intermediate.dense: 0.750
# Cosine similarity for concern bert.encoder.layer.8.output.dense: 0.063
# Cosine similarity for non_concern bert.encoder.layer.8.output.dense: 0.062
# Cosine similarity for concern bert.encoder.layer.9.attention.self.query: 0.393
# Cosine similarity for non_concern bert.encoder.layer.9.attention.self.query: 0.401
# Cosine similarity for concern bert.encoder.layer.9.attention.self.key: 0.329
# Cosine similarity for non_concern bert.encoder.layer.9.attention.self.key: 0.334
# Cosine similarity for concern bert.encoder.layer.9.attention.self.value: 0.117
# Cosine similarity for non_concern bert.encoder.layer.9.attention.self.value: 0.125
# Cosine similarity for concern bert.encoder.layer.9.attention.output.dense: 0.200
# Cosine similarity for non_concern bert.encoder.layer.9.attention.output.dense: 0.181
# Cosine similarity for concern bert.encoder.layer.9.intermediate.dense: 0.785
# Cosine similarity for non_concern bert.encoder.layer.9.intermediate.dense: 0.775
# Cosine similarity for concern bert.encoder.layer.9.output.dense: 0.080
# Cosine similarity for non_concern bert.encoder.layer.9.output.dense: 0.077
# Cosine similarity for concern bert.encoder.layer.10.attention.self.query: 0.386
# Cosine similarity for non_concern bert.encoder.layer.10.attention.self.query: 0.396
# Cosine similarity for concern bert.encoder.layer.10.attention.self.key: 0.363
# Cosine similarity for non_concern bert.encoder.layer.10.attention.self.key: 0.387
# Cosine similarity for concern bert.encoder.layer.10.attention.self.value: 0.140
# Cosine similarity for non_concern bert.encoder.layer.10.attention.self.value: 0.145
# Cosine similarity for concern bert.encoder.layer.10.attention.output.dense: 0.344
# Cosine similarity for non_concern bert.encoder.layer.10.attention.output.dense: 0.242
# Cosine similarity for concern bert.encoder.layer.10.intermediate.dense: 0.738
# Cosine similarity for non_concern bert.encoder.layer.10.intermediate.dense: 0.734
# Cosine similarity for concern bert.encoder.layer.10.output.dense: 0.119
# Cosine similarity for non_concern bert.encoder.layer.10.output.dense: 0.107
# Cosine similarity for concern bert.encoder.layer.11.attention.self.query: 0.450
# Cosine similarity for non_concern bert.encoder.layer.11.attention.self.query: 0.474
# Cosine similarity for concern bert.encoder.layer.11.attention.self.key: 0.400
# Cosine similarity for non_concern bert.encoder.layer.11.attention.self.key: 0.425
# Cosine similarity for concern bert.encoder.layer.11.attention.self.value: 0.176
# Cosine similarity for non_concern bert.encoder.layer.11.attention.self.value: 0.148
# Cosine similarity for concern bert.encoder.layer.11.attention.output.dense: 0.563
# Cosine similarity for non_concern bert.encoder.layer.11.attention.output.dense: 0.399
# Cosine similarity for concern bert.encoder.layer.11.intermediate.dense: 0.674
# Cosine similarity for non_concern bert.encoder.layer.11.intermediate.dense: 0.709
# Cosine similarity for concern bert.encoder.layer.11.output.dense: 0.251
# Cosine similarity for non_concern bert.encoder.layer.11.output.dense: 0.289
# Cosine similarity for concern bert.pooler.dense: 0.865
# Cosine similarity for non_concern bert.pooler.dense: 0.830
# Cosine similarity for concern classifier: 0.999
# Cosine similarity for non_concern classifier: 0.967

# %%
get_sparsity(module)
# Out:
# (0.2974067667308377,
#  {'bert.encoder.layer.0.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.0.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.0.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.0.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.0.attention.self.value.weight': 0.300048828125,
#   'bert.encoder.layer.0.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.0.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.0.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.0.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.0.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.0.output.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.0.output.dense.bias': 0.0,
#   'bert.encoder.layer.1.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.1.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.1.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.1.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.1.attention.self.value.weight': 0.2998792860243056,
#   'bert.encoder.layer.1.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.1.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.1.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.1.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.1.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.1.output.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.1.output.dense.bias': 0.0,
#   'bert.encoder.layer.2.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.2.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.2.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.2.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.2.attention.self.value.weight': 0.2999148898654514,
#   'bert.encoder.layer.2.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.2.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.2.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.2.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.2.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.2.output.dense.weight': 0.2997483147515191,
#   'bert.encoder.layer.2.output.dense.bias': 0.0,
#   'bert.encoder.layer.3.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.3.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.3.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.3.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.3.attention.self.value.weight': 0.3000217013888889,
#   'bert.encoder.layer.3.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.3.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.3.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.3.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.3.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.3.output.dense.weight': 0.29974110921223956,
#   'bert.encoder.layer.3.output.dense.bias': 0.0,
#   'bert.encoder.layer.4.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.4.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.4.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.4.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.4.attention.self.value.weight': 0.3001268174913194,
#   'bert.encoder.layer.4.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.4.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.4.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.4.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.4.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.4.output.dense.weight': 0.29979705810546875,
#   'bert.encoder.layer.4.output.dense.bias': 0.0,
#   'bert.encoder.layer.5.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.5.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.5.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.5.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.5.attention.self.value.weight': 0.3001115587022569,
#   'bert.encoder.layer.5.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.5.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.5.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.5.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.5.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.5.output.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.5.output.dense.bias': 0.0,
#   'bert.encoder.layer.6.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.6.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.6.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.6.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.6.attention.self.value.weight': 0.3000674777560764,
#   'bert.encoder.layer.6.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.6.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.6.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.6.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.6.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.6.output.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.6.output.dense.bias': 0.0,
#   'bert.encoder.layer.7.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.7.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.7.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.7.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.7.attention.self.value.weight': 0.3000335693359375,
#   'bert.encoder.layer.7.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.7.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.7.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.7.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.7.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.7.output.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.7.output.dense.bias': 0.0,
#   'bert.encoder.layer.8.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.8.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.8.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.8.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.8.attention.self.value.weight': 0.3001369900173611,
#   'bert.encoder.layer.8.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.8.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.8.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.8.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.8.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.8.output.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.8.output.dense.bias': 0.0,
#   'bert.encoder.layer.9.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.9.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.9.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.9.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.9.attention.self.value.weight': 0.2998911539713542,
#   'bert.encoder.layer.9.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.9.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.9.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.9.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.9.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.9.output.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.9.output.dense.bias': 0.0,
#   'bert.encoder.layer.10.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.10.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.10.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.10.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.10.attention.self.value.weight': 0.3004811604817708,
#   'bert.encoder.layer.10.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.10.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.10.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.10.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.10.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.10.output.dense.weight': 0.2997483147515191,
#   'bert.encoder.layer.10.output.dense.bias': 0.0,
#   'bert.encoder.layer.11.attention.self.query.weight': 0.2997402615017361,
#   'bert.encoder.layer.11.attention.self.query.bias': 0.0,
#   'bert.encoder.layer.11.attention.self.key.weight': 0.2997402615017361,
#   'bert.encoder.layer.11.attention.self.key.bias': 0.0,
#   'bert.encoder.layer.11.attention.self.value.weight': 0.3002777099609375,
#   'bert.encoder.layer.11.attention.self.value.bias': 0.0,
#   'bert.encoder.layer.11.attention.output.dense.weight': 0.2997402615017361,
#   'bert.encoder.layer.11.attention.output.dense.bias': 0.0,
#   'bert.encoder.layer.11.intermediate.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.11.intermediate.dense.bias': 0.0,
#   'bert.encoder.layer.11.output.dense.weight': 0.2997398376464844,
#   'bert.encoder.layer.11.output.dense.bias': 0.0,
#   'bert.pooler.dense.weight': 0.0,
#   'bert.pooler.dense.bias': 0.0,
#   'classifier.weight': 0.0,
#   'classifier.bias': 0.0})

# %%
# save_module(module, "Modules/", f"citi_{name}_{ci_ratio-ti_ratio}p.pt")

# %%
        # importance_score = torch.abs(current_weight) * torch.abs(2 * a - b)
