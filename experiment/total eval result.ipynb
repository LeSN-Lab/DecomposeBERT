# %% [markdown]
# # SDG

# %% [markdown]
# ![image.png](attachment:19a99d93-dfd2-4650-9a43-85718b46c6a9.png)

# %% [markdown]
# ![image.png](attachment:20625689-eb8d-4e2b-bd0b-663f3c92ec27.png)

# %% [markdown]
# ![image.png](attachment:c46642d9-2c7b-4027-8ff0-337e9c25f9cf.png)

# %% [markdown]
# ![image.png](attachment:b7547b7e-0328-4619-8b7c-9edff58f371e.png)

# %% [markdown]
# ![image.png](attachment:295aba31-13c5-40ef-8b94-50df5058e4d1.png)

# %% [markdown]
# ![image.png](attachment:532b68af-4d95-4c06-b15e-1be53abff3e6.png)

# %% [markdown]
# ![image.png](attachment:f2c8117e-2910-4a32-aefa-56b6505ade37.png)

# %% [markdown]
# ![image.png](attachment:273d7e2f-c623-4807-80e4-7748f89dd9ed.png)

# %% [markdown]
# ![image.png](attachment:2e3348c1-1861-439e-8672-9966c9ca6337.png)

# %% [markdown]
# ![image.png](attachment:677628c7-b73d-421d-8545-9a39b1af48b7.png)

# %% [markdown]
# ![image.png](attachment:9106457d-c309-484b-820d-4b54f7797f81.png)

# %% [markdown]
# ![image.png](attachment:100c99fb-cc31-4e0d-b65c-0bd61b6210d7.png)

# %% [markdown]
# ![image.png](attachment:619427dc-eafb-4983-9d64-3e492f1dc182.png)

# %% [markdown]
# ![image.png](attachment:9477659a-033a-46eb-8ab5-139e1312847d.png)

# %% [markdown]
# ![image.png](attachment:39522aae-89de-4467-ad1e-87564040b970.png)

# %% [markdown]
# ![image.png](attachment:1b4861cb-da06-4774-9a60-84e263707213.png)

# %% [markdown]
# ![image.png](attachment:d0131fc0-16c0-4a89-9194-cbdf5370c19f.png)

# %% [markdown]
# # yahoo

# %% [markdown]
# ## i = 0

# %% [markdown]
# ![image.png](attachment:fb10aada-64f7-40f5-973d-5a621441ab4f.png)

# %% [markdown]
# ## i=1

# %% [markdown]
# ![image.png](attachment:cfa82ca0-d7e4-4eaf-8853-c55ae8a9c860.png)
